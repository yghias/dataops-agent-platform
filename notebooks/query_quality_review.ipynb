# %% [markdown]
# # Query Quality Review
#
# Use this notebook to inspect SQL heuristic findings and review how optimization suggestions map to warehouse design constraints.

# %%
from tools.query_optimizer import QueryOptimizer

optimizer = QueryOptimizer()
optimizer.analyze('select * from analytics.orders order by order_ts')
