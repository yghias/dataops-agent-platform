# %% [markdown]
# # Agent Evaluation
#
# This notebook outlines a lightweight review loop for comparing specialist agent outputs by task type, quality score, and human approval outcome.

# %%
from workflows.intake_workflow import IntakeWorkflow

workflow = IntakeWorkflow()
packet = workflow.run('Optimize a slow revenue query against the orders fact table.')
packet['approval_packet']['quality_scores']
