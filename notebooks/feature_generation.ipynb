# %% [markdown]
# # Feature Generation
#
# This notebook sketches feature preparation for pipeline health prediction and operational anomaly analysis.

# %%
features = [
    'failed_runs_7d',
    'avg_runtime_seconds_7d',
    'freshness_breaches_7d',
    'avg_query_latency_ms_7d',
]
features
