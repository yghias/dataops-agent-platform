# %% [markdown]
# # Data Quality Checks
#
# Use this notebook to inspect duplicate, freshness, and reconciliation logic for platform metadata and operational marts.

# %%
from src.tools.sql_runner import SqlRunner

runner = SqlRunner()
runner.execute_file('sql/tests.sql')
